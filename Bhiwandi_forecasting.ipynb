# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./data/market/Bhiwandi.Rice.csv")
df['Price Date'] = pd.to_datetime(df['Price Date'], format='%d %b %Y').dt.strftime('%Y-%m-%d')
df.drop(['Min Price (Rs./Quintal)','Max Price (Rs./Quintal)',], axis=1, inplace = True)
df.rename(columns={'Modal Price (Rs./Quintal)':'Price', 'Price Date': 'Date'}, inplace = True)
df.set_index('Date', inplace = True)
df.sort_index(inplace = True)
df.index = pd.to_datetime(df.index)
df
# Out:
#             Price
# Date
# 2012-03-12   2900
# 2012-03-29   2150
# 2012-04-02   2900
# 2012-04-09   2900
# 2012-04-12   2900
# ...           ...
# 2021-12-15   1815
# 2021-12-17   1815
# 2021-12-20   1815
# 2021-12-22   1815
# 2021-12-27   1815
#
# [1205 rows x 1 columns]

# %%
df = df.resample('D').first()

df['Price'].interpolate(method='pchip', inplace=True)
df
# Out:
# /tmp/ipykernel_125319/3950296218.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].interpolate(method='pchip', inplace=True)
#                   Price
# Date
# 2012-03-12  2900.000000
# 2012-03-13  2775.279870
# 2012-03-14  2665.214736
# 2012-03-15  2568.888663
# 2012-03-16  2485.385711
# ...                 ...
# 2021-12-23  1815.000000
# 2021-12-24  1815.000000
# 2021-12-25  1815.000000
# 2021-12-26  1815.000000
# 2021-12-27  1815.000000
#
# [3578 rows x 1 columns]

# %%
df
# Out:
#                   Price
# Date
# 2012-03-12  2900.000000
# 2012-03-13  2775.279870
# 2012-03-14  2665.214736
# 2012-03-15  2568.888663
# 2012-03-16  2485.385711
# ...                 ...
# 2021-12-23  1815.000000
# 2021-12-24  1815.000000
# 2021-12-25  1815.000000
# 2021-12-26  1815.000000
# 2021-12-27  1815.000000
#
# [3578 rows x 1 columns]

# %%
df.describe().transpose()
# Out:
#         count         mean         std     min          25%          50%  \
# Price  3578.0  2449.817583  483.632902  1400.0  2081.384058  2385.578214
#
#                75%     max
# Price  2842.133415  4580.0

# %%
print(df['Price'].min())
# Out:
# 1400.0

# %%
print(df['Price'].min())
# Out:
# 1400.0

# %%
df.plot(figsize=(20, 4))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df, model="multiplicative")

# %%
result.resid.plot(figsize=(8, 5))
plt.ylabel("Price Deviation")
plt.show()

# %%
PREDICTION_DAYS = 28

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# %%
sequence_length = 56

# %%
X, y = [], []

sequences = []

for i in range(len(df) - sequence_length):
    X.append(scaled_data[i:(i + sequence_length)])
    y.append(scaled_data[(i + sequence_length)][0])

X = np.array(X)
y = np.array(y)

# %%
X.shape, y.shape
# Out:
# ((3522, 56, 1), (3522,))

# %%
split = int(0.8 * len(X))

# %%
X_train, X_val = X[:split], X[split:]
y_train, y_val = y[:split], y[split:]

# %%
X_train.shape
y_train.shape
# Out:
# (2817,)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

model = Sequential(
    [
        LSTM(units=64, return_sequences=True, activation="relu", input_shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(units=64, return_sequences=False),
        Dense(units=1),
    ]
)

model.compile(optimizer="adam", loss="mean_squared_error")
# Out:
# 2024-03-08 16:46:23.002147: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-08 16:46:23.047997: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-08 16:46:23.048053: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-08 16:46:23.049449: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-08 16:46:23.059020: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-08 16:46:23.059776: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-08 16:46:24.014267: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-03-08 16:46:24.490430: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-08 16:46:24.490975: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 56, 64)            16896
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 49985 (195.25 KB)
# Trainable params: 49985 (195.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=28, epochs=50, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 101/101 [==============================] - 6s 37ms/step - loss: 0.0164 - val_loss: 9.2410e-04
# Epoch 2/50
# 101/101 [==============================] - 4s 36ms/step - loss: 0.0080 - val_loss: 0.0020
# Epoch 3/50
# 101/101 [==============================] - 4s 36ms/step - loss: 0.0074 - val_loss: 0.0010
# Epoch 4/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0065 - val_loss: 8.1451e-04
# Epoch 5/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0057 - val_loss: 5.3397e-04
# Epoch 6/50
# 101/101 [==============================] - 4s 35ms/step - loss: 0.0048 - val_loss: 6.3739e-04
# Epoch 7/50
# 101/101 [==============================] - 4s 35ms/step - loss: 0.0044 - val_loss: 6.2299e-04
# Epoch 8/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0045 - val_loss: 9.6966e-04
# Epoch 9/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0042 - val_loss: 5.3437e-04
# Epoch 10/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0041 - val_loss: 9.1486e-04
# Epoch 11/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0042 - val_loss: 0.0013
# Epoch 12/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0039 - val_loss: 3.9215e-04
# Epoch 13/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0039 - val_loss: 7.6715e-04
# Epoch 14/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0039 - val_loss: 6.0651e-04
# Epoch 15/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0039 - val_loss: 4.2797e-04
# Epoch 16/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0038 - val_loss: 5.0619e-04
# Epoch 17/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0039 - val_loss: 4.4522e-04
# Epoch 18/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0040 - val_loss: 3.7051e-04
# Epoch 19/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0039 - val_loss: 4.1690e-04
# Epoch 20/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0039 - val_loss: 4.5826e-04
# Epoch 21/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0038 - val_loss: 7.1302e-04
# Epoch 22/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.8006e-04
# Epoch 23/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0037 - val_loss: 7.8234e-04
# Epoch 24/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.9561e-04
# Epoch 25/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0039 - val_loss: 4.7471e-04
# Epoch 26/50
# 101/101 [==============================] - 3s 30ms/step - loss: 0.0038 - val_loss: 6.1899e-04
# Epoch 27/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 4.0544e-04
# Epoch 28/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.7309e-04
# Epoch 29/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 7.4211e-04
# Epoch 30/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0037 - val_loss: 3.6452e-04
# Epoch 31/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.6176e-04
# Epoch 32/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.6619e-04
# Epoch 33/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0038 - val_loss: 8.8447e-04
# Epoch 34/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 4.4246e-04
# Epoch 35/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 5.7541e-04
# Epoch 36/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.9591e-04
# Epoch 37/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0038 - val_loss: 4.6201e-04
# Epoch 38/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.7312e-04
# Epoch 39/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 7.5226e-04
# Epoch 40/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 8.1268e-04
# Epoch 41/50
# 101/101 [==============================] - 4s 36ms/step - loss: 0.0037 - val_loss: 3.6961e-04
# Epoch 42/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0037 - val_loss: 6.7188e-04
# Epoch 43/50
# 101/101 [==============================] - 3s 35ms/step - loss: 0.0037 - val_loss: 4.0301e-04
# Epoch 44/50
# 101/101 [==============================] - 4s 38ms/step - loss: 0.0037 - val_loss: 4.3968e-04
# Epoch 45/50
# 101/101 [==============================] - 4s 38ms/step - loss: 0.0037 - val_loss: 4.5254e-04
# Epoch 46/50
# 101/101 [==============================] - 4s 38ms/step - loss: 0.0038 - val_loss: 0.0012
# Epoch 47/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0038 - val_loss: 4.1909e-04
# Epoch 48/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0037 - val_loss: 4.8088e-04
# Epoch 49/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0037 - val_loss: 3.7748e-04
# Epoch 50/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0038 - val_loss: 6.5601e-04

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

# %%
from joblib import dump, load

# %%
from sklearn.pipeline import Pipeline

dump(
    Pipeline([("scaler", scaler), ("model", model)]),
    "./out/forecast.LSTM.Bhiwandi.joblib",
)
# Out:
# ['./out/forecast.LSTM.Bhiwandi.joblib']

# %%
x_test = scaled_data[-sequence_length:]
x_test = np.array([x_test])

# %%
x_test.shape
# Out:
# (1, 56, 1)

# %%
X.shape
# Out:
# (3522, 56, 1)

# %%
predictions = model.predict(X)
# Out:
# 111/111 [==============================] - 2s 11ms/step

# %%
predictions = predictions.reshape(-1,1)
predictions = scaler.inverse_transform(predictions).flatten()

# %%
from datetime import timedelta

# %%
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 29)]

# %%
plt.figure(figsize=(20, 4))
plt.plot(df.index, df['Price'], label='Original Data', c="#666666")
plt.plot(df.index[sequence_length:], predictions, label='Predicted Prices', c="#00000088")
plt.title('Time Series Forecasting with LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

(
    mean_absolute_error(predictions, df["Price"][sequence_length:]),
    mean_squared_error(predictions, df["Price"][sequence_length:], squared=False),
)
# Out:
# C:\Users\jatin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (90.9277817227143, 173.6855468900594)
