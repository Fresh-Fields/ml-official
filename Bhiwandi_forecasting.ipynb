# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("./data/market/Bhivandi.Rice.csv")
df['Price Date'] = pd.to_datetime(df['Price Date'], format='%d %b %Y').dt.strftime('%Y-%m-%d')
df.drop(['Min Price (Rs./Quintal)','Max Price (Rs./Quintal)',], axis=1, inplace = True)
df.rename(columns={'Modal Price (Rs./Quintal)':'Price', 'Price Date': 'Date'}, inplace = True)
df.set_index('Date', inplace = True)
df.sort_index(inplace = True)
df.index = pd.to_datetime(df.index)
df
# Out:
#             Price
# Date
# 2012-03-12   2900
# 2012-03-29   2150
# 2012-04-02   2900
# 2012-04-09   2900
# 2012-04-12   2900
# ...           ...
# 2021-12-15   1815
# 2021-12-17   1815
# 2021-12-20   1815
# 2021-12-22   1815
# 2021-12-27   1815
#
# [1205 rows x 1 columns]

# %%
df = df.resample('D').first()

df['Price'].interpolate(method='pchip', inplace=True)
df
# Out:
# C:\Users\jatin\AppData\Local\Temp\ipykernel_23308\3950296218.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].interpolate(method='pchip', inplace=True)
#                   Price
# Date
# 2012-03-12  2900.000000
# 2012-03-13  2775.279870
# 2012-03-14  2665.214736
# 2012-03-15  2568.888663
# 2012-03-16  2485.385711
# ...                 ...
# 2021-12-23  1815.000000
# 2021-12-24  1815.000000
# 2021-12-25  1815.000000
# 2021-12-26  1815.000000
# 2021-12-27  1815.000000
#
# [3578 rows x 1 columns]

# %%
df
# Out:
#                   Price
# Date
# 2012-03-12  2900.000000
# 2012-03-13  2775.279870
# 2012-03-14  2665.214736
# 2012-03-15  2568.888663
# 2012-03-16  2485.385711
# ...                 ...
# 2021-12-23  1815.000000
# 2021-12-24  1815.000000
# 2021-12-25  1815.000000
# 2021-12-26  1815.000000
# 2021-12-27  1815.000000
#
# [3578 rows x 1 columns]

# %%
df.describe().transpose()
# Out:
#         count         mean         std     min          25%          50%  \
# Price  3578.0  2449.817583  483.632902  1400.0  2081.384058  2385.578214
#
#                75%     max
# Price  2842.133415  4580.0

# %%
print(df['Price'].min())
# Out:
# 1400.0

# %%
print(df['Price'].min())
# Out:
# 1400.0

# %%
df.plot(figsize=(20, 4))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df, model="multiplicative")

# %%
result.resid.plot(figsize=(8, 5))
plt.ylabel("Price Deviation")
plt.show()

# %%
PREDICTION_DAYS = 28

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# %%
sequence_length = 56

# %%
X, y = [], []

sequences = []

for i in range(len(df) - sequence_length):
    X.append(scaled_data[i:(i + sequence_length)])
    y.append(scaled_data[(i + sequence_length)][0])

X = np.array(X)
y = np.array(y)

# %%
X.shape, y.shape
# Out:
# ((3522, 56, 1), (3522,))

# %%
split = int(0.8 * len(X))

# %%
X_train, X_val = X[:split], X[split:]
y_train, y_val = y[:split], y[split:]

# %%
X_train.shape
y_train.shape
# Out:
# (2817,)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

model = Sequential(
    [
        LSTM(units=64, return_sequences=True, activation="relu", input_shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(units=64, return_sequences=False),
        Dense(units=1),
    ]
)

model.compile(optimizer="adam", loss="mean_squared_error")

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 56, 64)            16896
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 49985 (195.25 KB)
# Trainable params: 49985 (195.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=28, epochs=50, validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 101/101 [==============================] - 6s 35ms/step - loss: 0.0177 - val_loss: 0.0022
# Epoch 2/50
# 101/101 [==============================] - 3s 28ms/step - loss: 0.0079 - val_loss: 0.0011
# Epoch 3/50
# 101/101 [==============================] - 3s 29ms/step - loss: 0.0068 - val_loss: 7.1651e-04
# Epoch 4/50
# 101/101 [==============================] - 3s 32ms/step - loss: 0.0060 - val_loss: 0.0027
# Epoch 5/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0060 - val_loss: 9.0040e-04
# Epoch 6/50
# 101/101 [==============================] - 3s 30ms/step - loss: 0.0050 - val_loss: 4.6507e-04
# Epoch 7/50
# 101/101 [==============================] - 3s 30ms/step - loss: 0.0043 - val_loss: 3.7713e-04
# Epoch 8/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0041 - val_loss: 3.6838e-04
# Epoch 9/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0043 - val_loss: 6.1668e-04
# Epoch 10/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0041 - val_loss: 6.2361e-04
# Epoch 11/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0040 - val_loss: 3.7454e-04
# Epoch 12/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0040 - val_loss: 6.7318e-04
# Epoch 13/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0040 - val_loss: 7.8006e-04
# Epoch 14/50
# 101/101 [==============================] - 3s 30ms/step - loss: 0.0039 - val_loss: 3.7906e-04
# Epoch 15/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0040 - val_loss: 4.5096e-04
# Epoch 16/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0039 - val_loss: 5.0260e-04
# Epoch 17/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0039 - val_loss: 3.6799e-04
# Epoch 18/50
# 101/101 [==============================] - 4s 36ms/step - loss: 0.0040 - val_loss: 3.9985e-04
# Epoch 19/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0039 - val_loss: 5.0807e-04
# Epoch 20/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 5.0675e-04
# Epoch 21/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0038 - val_loss: 6.3980e-04
# Epoch 22/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0038 - val_loss: 3.7101e-04
# Epoch 23/50
# 101/101 [==============================] - 3s 31ms/step - loss: 0.0040 - val_loss: 4.6635e-04
# Epoch 24/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0038 - val_loss: 3.8406e-04
# Epoch 25/50
# 101/101 [==============================] - 3s 33ms/step - loss: 0.0039 - val_loss: 3.8557e-04
# Epoch 26/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0038 - val_loss: 3.8953e-04
# Epoch 27/50
# 101/101 [==============================] - 4s 37ms/step - loss: 0.0038 - val_loss: 4.1477e-04
# Epoch 28/50
# 101/101 [==============================] - 4s 36ms/step - loss: 0.0038 - val_loss: 3.6653e-04
# Epoch 29/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0038 - val_loss: 4.1836e-04
# Epoch 30/50
# 101/101 [==============================] - 3s 34ms/step - loss: 0.0038 - val_loss: 3.8111e-04
# Epoch 31/50
# 101/101 [==============================] - 4s 37ms/step - loss: 0.0038 - val_loss: 4.4190e-04
# Epoch 32/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 7.5255e-04
# Epoch 33/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0038 - val_loss: 4.3777e-04
# Epoch 34/50
# 101/101 [==============================] - 4s 41ms/step - loss: 0.0037 - val_loss: 5.0780e-04
# Epoch 35/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0038 - val_loss: 3.8240e-04
# Epoch 36/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0037 - val_loss: 3.9627e-04
# Epoch 37/50
# 101/101 [==============================] - 4s 42ms/step - loss: 0.0037 - val_loss: 5.3577e-04
# Epoch 38/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 6.1102e-04
# Epoch 39/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 5.0769e-04
# Epoch 40/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 7.9395e-04
# Epoch 41/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0038 - val_loss: 4.0581e-04
# Epoch 42/50
# 101/101 [==============================] - 4s 38ms/step - loss: 0.0039 - val_loss: 7.3076e-04
# Epoch 43/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0037 - val_loss: 3.7219e-04
# Epoch 44/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0037 - val_loss: 4.0702e-04
# Epoch 45/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0038 - val_loss: 4.2039e-04
# Epoch 46/50
# 101/101 [==============================] - 4s 40ms/step - loss: 0.0037 - val_loss: 4.5399e-04
# Epoch 47/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 5.1996e-04
# Epoch 48/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 4.3046e-04
# Epoch 49/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 4.6742e-04
# Epoch 50/50
# 101/101 [==============================] - 4s 39ms/step - loss: 0.0037 - val_loss: 4.3575e-04

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

# %%
from joblib import dump, load

# %%
#model = load("./out/forecast.LSTM.Vasai.joblib")

# %%
x_test = scaled_data[-sequence_length:]
x_test = np.array([x_test])

# %%
x_test.shape
# Out:
# (1, 56, 1)

# %%
predictions = model.predict(X)
# Out:
# 111/111 [==============================] - 2s 13ms/step

# %%
predictions = predictions.reshape(-1,1)
predictions = scaler.inverse_transform(predictions).flatten()

# %%
from datetime import timedelta

# %%
future_dates = [df.index[-1] + timedelta(days=i) for i in range(1, 29)]

# %%
plt.figure(figsize=(20, 4))
plt.plot(df.index, df['Price'], label='Original Data', c="#666666")
plt.plot(df.index[sequence_length:], predictions, label='Predicted Prices', c="#00000088")
plt.title('Time Series Forecasting with LSTM')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

(
    mean_absolute_error(predictions, df["Price"][sequence_length:]),
    mean_squared_error(predictions, df["Price"][sequence_length:], squared=False),
)
# Out:
# C:\Users\jatin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# (95.31621019214175, 173.03358126741713)
